# %%
import phoebe 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline 

logger = phoebe.logger(clevel = 'WARNING')

# %% [markdown]
# # Round 3

# %%
b = phoebe.open('/Users/karan/Documents/GitHub/Eclipsing-Binary-Modeling/bundles/round_2.bundle')

# %%
b['continue_from@mcmc'] = 'round_2'

# %%
b.run_solver('mcmc', solution = 'round_3')
# Out:
# 100%|██████████| 100/100 [6:52:38<00:00, 249.17s/it] Wed, 14 Aug 2024 13:33 emcee.autocorr WARNING The chain is shorter than 50 times the integrated autocorrelation time for 11 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 12;
# tau: [46.38213737 67.15913904 82.15963752 79.40289731 81.79237152 82.17887138
#  34.29738441 82.28588885 82.42753271 39.32471867 80.2459964 ]
# 100%|██████████| 100/100 [6:52:38<00:00, 247.59s/it]
# <ParameterSet: 20 parameters | qualifiers: fitted_twigs, nlags, progress, lnprobabilities, comments, autocorr_times, samples, acceptance_fractions, burnin, failed_samples, wrap_central_values, lnprob_cutoff, distributions_convert, adopt_distributions, niters, adopt_parameters, fitted_units, adopt_values, thin, nwalkers>

# %%
b.plot(solution = 'round_2', style = 'lnprobability', burnin = 130, thin = 1, show = True)
b.plot(solution = 'round_3', style = 'lnprobability', burnin = 130, thin = 1, show = True)
# Out:
# (<autofig.figure.Figure | 1 axes | 24 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b['continue_from@mcmc'] = 'round_3'

# %%
b.run_solver('mcmc', solution = 'round_3', overwrite = True)
# Out:
# 100%|██████████| 100/100 [6:31:38<00:00, 240.89s/it] Wed, 14 Aug 2024 23:05 emcee.autocorr WARNING The chain is shorter than 50 times the integrated autocorrelation time for 11 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 14;
# tau: [67.73815741 76.84479022 93.59755103 94.74799761 95.17413405 93.79763035
#  59.1582097  93.66243929 94.9783088  48.46673179 94.23498584]
# 100%|██████████| 100/100 [6:31:38<00:00, 234.98s/it]
# <ParameterSet: 20 parameters | qualifiers: samples, adopt_distributions, burnin, lnprobabilities, nlags, lnprob_cutoff, nwalkers, fitted_units, niters, fitted_twigs, thin, adopt_parameters, distributions_convert, comments, autocorr_times, wrap_central_values, adopt_values, acceptance_fractions, progress, failed_samples>

# %%
b.plot(solution = 'round_2', style = 'lnprobability', burnin = 130, thin = 1, show = True)
b.plot(solution = 'round_3', style = 'lnprobability', burnin = 130, thin = 1, show = True)
# Out:
# (<autofig.figure.Figure | 1 axes | 24 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b['continue_from@mcmc'] = 'round_3'

# %%
b.run_solver('mcmc', solution = 'round_3', overwrite = True)
# Out:
# 100%|██████████| 100/100 [7:06:44<00:00, 245.68s/it] Thu, 15 Aug 2024 18:32 emcee.autocorr WARNING The chain is shorter than 50 times the integrated autocorrelation time for 11 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 16;
# tau: [ 84.74597473  85.80439454 102.86876354 108.39842913 106.39207468
#  103.10932087  86.48268187 102.05908962 107.33242128  58.09094757
#  107.14860119]
# 100%|██████████| 100/100 [7:06:44<00:00, 256.05s/it]
# <ParameterSet: 20 parameters | qualifiers: thin, fitted_units, niters, wrap_central_values, nwalkers, failed_samples, distributions_convert, lnprob_cutoff, nlags, progress, acceptance_fractions, burnin, comments, autocorr_times, adopt_values, lnprobabilities, adopt_parameters, samples, fitted_twigs, adopt_distributions>

# %%
b.plot(solution = 'round_2', style = 'lnprobability', burnin = 130, thin = 1, show = True)
b.plot(solution = 'round_3', style = 'lnprobability', burnin = 130, thin = 1, show = True)
# Out:
# (<autofig.figure.Figure | 1 axes | 24 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b['continue_from@mcmc'] = 'round_3'

# %%
b.run_solver('mcmc', solution = 'round_3', overwrite = True)
# Out:
# 100%|██████████| 100/100 [7:04:33<00:00, 238.05s/it] Fri, 16 Aug 2024 13:25 emcee.autocorr WARNING The chain is shorter than 50 times the integrated autocorrelation time for 11 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 18;
# tau: [ 94.65287942  93.14322959 100.98715401 116.26274199 108.97886384
#  103.68050704  86.46252026  99.82977669 119.179424    61.51771819
#  106.36425228]
# 100%|██████████| 100/100 [7:04:33<00:00, 254.74s/it]
# <ParameterSet: 20 parameters | qualifiers: adopt_distributions, autocorr_times, failed_samples, progress, wrap_central_values, adopt_parameters, adopt_values, lnprob_cutoff, comments, distributions_convert, thin, lnprobabilities, acceptance_fractions, fitted_units, burnin, niters, nwalkers, nlags, samples, fitted_twigs>

# %%
b.plot(solution = 'round_2', style = 'lnprobability', burnin = 130, thin = 1, show = True)
b.plot(solution = 'round_3', style = 'lnprobability', burnin = 130, thin = 1, show = True)
# Out:
# (<autofig.figure.Figure | 1 axes | 24 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b['continue_from@mcmc'] = 'round_3'

# %%
b.run_solver('mcmc', solution = 'round_3', overwrite = True)
# Out:
# 100%|██████████| 100/100 [6:40:15<00:00, 243.28s/it] Sat, 17 Aug 2024 13:26 emcee.autocorr WARNING The chain is shorter than 50 times the integrated autocorrelation time for 11 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 20;
# tau: [102.57881595  99.53574414  94.53493544 121.25379563 107.37178065
#  100.12494365  71.01373725  94.50926888 131.64807613  64.39647056
#   99.81524652]
# 100%|██████████| 100/100 [6:40:15<00:00, 240.15s/it]
# <ParameterSet: 20 parameters | qualifiers: burnin, lnprob_cutoff, samples, distributions_convert, niters, comments, lnprobabilities, progress, wrap_central_values, thin, adopt_distributions, adopt_parameters, acceptance_fractions, adopt_values, autocorr_times, nlags, fitted_units, failed_samples, nwalkers, fitted_twigs>

# %%
b.plot(solution = 'round_2', style = 'lnprobability', burnin = 130, thin = 1, show = True)
b.plot(solution = 'round_3', style = 'lnprobability', burnin = 130, thin = 1, show = True)
# Out:
# (<autofig.figure.Figure | 1 axes | 24 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
print('burnin iterations for round_2 is: %d' % 
      (int(max(b['value@autocorr_times@round_2']) * b['value@burnin_factor@mcmc'])))

print('burnin iterations for round_3 is: %d' % 
      (int(max(b['value@autocorr_times@round_3']) * b['value@burnin_factor@mcmc'])))
# Out:
# burnin iterations for round_2 is: 130
# burnin iterations for round_3 is: 263

# %%
b.plot(solution = 'round_3', style = 'corner', burnin = 263, thin = 1, show = True)
# Out:
# (None, <Figure size 2440x2440 with 121 Axes>)

# %%
b.save('round_3.bundle')
# Out:
# 'round_3.bundle'

# %% [markdown]
# # Round 4

# %%
b = phoebe.open('/Users/karan/Documents/GitHub/Eclipsing-Binary-Modeling/bundles/round_3.bundle')

# %%
b['continue_from@mcmc'] = 'round_3'

# %%
b.run_solver('mcmc', solution = 'round_4')
# Out:
# 100%|██████████| 100/100 [6:43:57<00:00, 241.50s/it] Sat, 17 Aug 2024 23:02 emcee.autocorr WARNING The chain is shorter than 50 times the integrated autocorrelation time for 11 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 22;
# tau: [110.46280475 105.79015744  93.53148059 125.92906273 106.01842021
#   98.86284681  67.87671446  93.40813937 144.38604929  67.79492611
#   97.06136146]
# 100%|██████████| 100/100 [6:43:57<00:00, 242.37s/it]
# <ParameterSet: 20 parameters | qualifiers: samples, thin, lnprobabilities, burnin, comments, nwalkers, wrap_central_values, lnprob_cutoff, adopt_parameters, acceptance_fractions, autocorr_times, fitted_twigs, distributions_convert, progress, failed_samples, adopt_values, adopt_distributions, nlags, niters, fitted_units>

# %%
b.plot(solution = 'round_3', style = 'lnprobability', burnin = 263, thin = 1, show = True)
b.plot(solution = 'round_4', style = 'lnprobability', burnin = 263, thin = 1, show = True)
# Out:
# (<autofig.figure.Figure | 1 axes | 24 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b.save('round_4.bundle')
# Out:
# 'round_4.bundle'

# %%
b = phoebe.open('/Users/karan/Documents/GitHub/Eclipsing-Binary-Modeling/bundles/round_4.bundle')

# %%
b['continue_from@mcmc'] = 'round_4'

# %%
b.run_solver('mcmc', solution = 'round_4', overwrite = True)
# Out:
# 100%|██████████| 100/100 [6:37:06<00:00, 240.70s/it] Sun, 18 Aug 2024 18:12 emcee.autocorr WARNING The chain is shorter than 50 times the integrated autocorrelation time for 11 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 24;
# tau: [117.68565829 111.55555831  94.00891674 130.76690907 105.69383905
#   99.25724605  73.17480629  93.91466853 156.53514437  71.71620919
#   96.76388466]
# 100%|██████████| 100/100 [6:37:06<00:00, 238.27s/it]
# <ParameterSet: 20 parameters | qualifiers: comments, fitted_units, failed_samples, adopt_parameters, progress, distributions_convert, adopt_distributions, wrap_central_values, acceptance_fractions, nlags, fitted_twigs, niters, autocorr_times, lnprobabilities, adopt_values, samples, thin, lnprob_cutoff, burnin, nwalkers>

# %%
b.plot(solution = 'round_3', style = 'lnprobability', burnin = 263, thin = 1, show = True)
b.plot(solution = 'round_4', style = 'lnprobability', burnin = 263, thin = 1, show = True)
# Out:
# (<autofig.figure.Figure | 1 axes | 24 call(s)>,
#  <Figure size 800x600 with 1 Axes>)

# %%
b.save('round_4.bundle')
# Out:
# 'round_4.bundle'
